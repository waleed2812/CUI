# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
a = np.array([
    [115, 0.7, 1300000],
    [135, 5, 800000],
    [180, 2, 2100000],
    [200, 3.5, 2100000],
    [240, 1, 2700000],
    [300, 2.5, 2900000],
    [370, 4, 3500000],
    [450, 2, 5500000],
    [500, 3, 6000000],
    [700, 4, 8000000]    
])

a[0]
# Out:
# array([1.15e+02, 7.00e-01, 1.30e+06])

# %%
C = (np.linalg.inv(((a.transpose()).dot(a)))).dot(a.transpose())

C
# Out:
# array([[ 4.36639350e-04, -2.41117319e-03, -4.85747409e-03,
#         -6.04225556e-03,  3.28930611e-03,  8.92649009e-03,
#          8.54414926e-03, -4.05573058e-03, -5.58141690e-03,
#          1.92166114e-03],
#        [-9.40846738e-03,  1.74840728e-01,  1.00745579e-01,
#          1.64968155e-01, -7.16493429e-02, -1.21168771e-01,
#         -8.07029957e-02,  2.65940346e-02,  7.22881237e-02,
#         -5.47916501e-02],
#        [-2.52188217e-08,  1.12788712e-07,  3.80697106e-07,
#          4.46784916e-07, -2.31401157e-07, -6.97993975e-07,
#         -6.84944811e-07,  3.74431112e-07,  4.84648154e-07,
#         -8.95182874e-08]])

# %%
fig = plt.figure(figsize=(8, 6), dpi=80)

ax = plt.axes(projection='3d')

ax.scatter3D(a[:, 0], a[:, 1], a[:, 2], cmap='Green');
